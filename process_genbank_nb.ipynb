# %%
# load python script

from genbank_utils import genbank_to_metadata

# %% [markdown]
# ### Extract metadata from genbank files
#
# The cells below illustrate how to extract metadata from genbank files. For non-segmented viruses use `process_gb`, and for segmented viruses use `process_gb_seg`.

# %%
# Non-segmented viruses

gb_file = "test_folder/test.gb"
working_dir = "test_folder/output"
virus_family = "parahenipavirus"


genbank_to_metadata.process_gb(gb_file, working_dir, virus_family)

# %%
# Segmented viruses

gb_file = "test_folder"
working_dir = "test_folder/output"
virus_family = "parahenipavirus"


genbank_to_metadata.process_gb_seg(gb_file, working_dir, virus_family)

# %% [markdown]
# ### Extract sequences and metadata from genbank files
#
# The cells below illustrate how to extract metadata and sequences from genbank files. For non-segmented viruses use `process_gb_to_fasta`. Method for processing segmented viruses will available soon.

# %%
# Non-segmented viruses

gb_file = "test_folder/test.gb"
working_dir = "test_folder/output"
virus_family = "parahenipavirus"

genbank_to_metadata.process_gb_to_fasta(gb_file, working_dir, virus_family)

# %% [markdown]
# ### Renaming sequence names
#
# Rename sequence names in a fasta alignment file using extracted metadata file from process_gb* methods

# %%
aln_file = "test_folder/rhabdo_data/Rhabdo_align_2_trimmed_clipped_rmdups.fasta"
metadata_file = "test_folder/rhabdo_data/output/rhabdovirus_v3_metadata.csv"

genbank_to_metadata.rename_fasta(aln_file, metadata_file)
# Out:
# /Users/jayna/PycharmProjects/processGenbank/genbank_utils/genbank_to_metadata.py:805: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   metadata.s = metadata[metadata.Accession_no == acc]
